# %% [markdown]
# # Feature Reduction using ICA

# %%
import  mne
import matplotlib.pyplot

# %%
file = "feature_files/merged-normal-raw.fif"

# %%
raw = mne.io.read_raw_fif(file, preload=True)
# Out:
# Opening raw data file feature_files/merged-normal-raw.fif...
# Isotrak not found
#     Range : 0 ... 417535 =      0.000 ...  3261.992 secs
# Ready.
# Reading 0 ... 417535  =      0.000 ...  3261.992 secs...

# %%
dir(raw)
# Out:
# ['__class__',
#  '__contains__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotations',
#  '_cals',
#  '_check_bad_segment',
#  '_comp',
#  '_data',
#  '_dtype',
#  '_dtype_',
#  '_filenames',
#  '_first_samps',
#  '_first_time',
#  '_get_buffer_size',
#  '_get_channel_positions',
#  '_init_kwargs',
#  '_last_samps',
#  '_last_time',
#  '_orig_units',
#  '_parse_get_set_params',
#  '_pick_drop_channels',
#  '_pick_projs',
#  '_preload_data',
#  '_projector',
#  '_projectors',
#  '_raw_extras',
#  '_raw_lengths',
# ...

# %%
# raw.plot()
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
# Out:
# <Raw | merged-normal-raw.fif, 8 x 417536 (3262.0 s), ~25.5 MB, data loaded>

# %%
ica = mne.preprocessing.ICA(n_components=7, random_state=0)

# %%
ica.fit(raw.copy().filter(1, 40))
# Out:
# Filtering raw data in 6 contiguous segments
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 sec)
#
# Fitting ICA to data using 7 channels (please be patient, this may take a while)
# Selecting by number: 7 components
# Fitting ICA took 4.5s.
# <ICA | raw data decomposition, fit (fastica): 417536 samples, 7 components, channels used: "eeg">

# %%
ica.plot_components(outlines="skirt")
# Out:
# [<Figure size 702x339.12 with 7 Axes>]

# %%
ica.save('merged-normal-ica.fif')
# Out:
# Writing ICA solution to merged-normal-ica.fif...
# <ICA | raw data decomposition, fit (fastica): 417536 samples, 7 components, channels used: "eeg">

# %%
import  mne
import matplotlib.pyplot

# %%
file = "feature_files/merged-autism-raw.fif"

# %%
raw = mne.io.read_raw_fif(file, preload=True)
# Out:
# Opening raw data file feature_files/merged-autism-raw.fif...
# Isotrak not found
#     Range : 0 ... 599551 =      0.000 ...  4683.992 secs
# Ready.
# Reading 0 ... 599551  =      0.000 ...  4683.992 secs...

# %%
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
# Out:
# <Raw | merged-autism-raw.fif, 8 x 599552 (4684.0 s), ~36.6 MB, data loaded>

# %%
ica = mne.preprocessing.ICA(n_components=7, random_state=0)

# %%
ica.fit(raw.copy().filter(1, 40))
ica.plot_components(outlines="skirt")
# Out:
# Filtering raw data in 8 contiguous segments
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 sec)
#
# Fitting ICA to data using 7 channels (please be patient, this may take a while)
# Selecting by number: 7 components
# Fitting ICA took 7.8s.
# [<Figure size 702x339.12 with 7 Axes>]

# %%
ica.save('merged-autism-ica.fif')
# Out:
# Writing ICA solution to merged-autism-ica.fif...
# <ICA | raw data decomposition, fit (fastica): 599552 samples, 7 components, channels used: "eeg">
