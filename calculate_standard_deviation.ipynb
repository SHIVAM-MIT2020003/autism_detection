# %% [markdown]
# # Calculating Standard deviation for both the files

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('feature_files/normalized_merged_normal.csv', keep_default_na=False, na_values=[""])
df
# Out:
#                0         1         2         3         4         5         6
# 0       0.479505  0.823736  0.505324  0.522786  0.504790  0.502587  0.385726
# 1       0.480316  0.820011  0.508086  0.520821  0.487508  0.499314  0.388539
# 2       0.475412  0.815755  0.505496  0.522743  0.513204  0.502672  0.387648
# 3       0.471016  0.815389  0.500450  0.530000  0.554304  0.509673  0.386068
# 4       0.473008  0.815652  0.501184  0.533240  0.555081  0.511193  0.387307
# ...          ...       ...       ...       ...       ...       ...       ...
# 417531  0.413462  0.777803  0.359424  0.332613  0.150162  0.404013  0.108423
# 417532  0.413462  0.777803  0.359424  0.332613  0.150162  0.404013  0.108423
# 417533  0.413462  0.777803  0.359424  0.332613  0.150162  0.404013  0.108423
# 417534  0.413462  0.777803  0.359424  0.332613  0.150162  0.404013  0.108423
# 417535  0.413462  0.777803  0.359424  0.332613  0.150162  0.404013  0.108423
#
# [417536 rows x 7 columns]

# %%
table = {}
for i in range(7):
    col = str(i)
    N = len(df[col])
    var = []
    for j in range(0, N, 120):
        var.append(df[col][j:j + 120].std())
    table[col] = var
print(table)
# Out:
# {'0': [0.006850763943969027, 0.006155417721949412, 0.009986162626711953, 0.010976441744458368, 0.008449664427379131, 0.009979606634021667, 0.006337626378873085, 0.009807970286720244, 0.010490602283262578, 0.009713360505817255, 0.00840593641379664, 0.0045347318565321865, 0.007503553491416974, 0.006642380429966668, 0.0063373670989050924, 0.005267734929811367, 0.01252530525652183, 0.009331828887639441, 0.005138244422647917, 0.005518035234486483, 0.0070125806788628115, 0.004928467931291529, 0.0048619614493237385, 0.005335191344068499, 0.007171251155382117, 0.0055593172180650255, 0.005217147093094063, 0.009675546015236125, 0.005015916700898896, 0.005131441796138692, 0.005764415402889272, 0.03923012305158483, 0.009216938465118655, 0.012377824037625638, 0.0051975572780313265, 0.007006892402059711, 0.007989953032743724, 0.007142079679379015, 0.006782176102333367, 0.008208067489369107, 0.004629233577520701, 0.004890916544158662, 0.006545348556434077, 0.016809940738382212, 0.005500583524202011
# ...

# %%
result = pd.DataFrame(table)
result.to_csv('feature_files/standard_deviation_normalized_merged_normal.csv')

# %%
df2 = pd.read_csv('feature_files/normalized_merged_autism.csv', keep_default_na=False, na_values=[""])
df2
# Out:
#                0         1         2         3         4         5         6
# 0       0.522377  0.407020  0.511221  0.467724  0.502836  0.523301  0.447376
# 1       0.522218  0.407093  0.511092  0.469672  0.502339  0.523239  0.446236
# 2       0.521101  0.406125  0.511598  0.468475  0.501882  0.523815  0.445361
# 3       0.519353  0.404762  0.510323  0.466965  0.503116  0.524641  0.445295
# 4       0.518256  0.405134  0.508125  0.469881  0.504702  0.524646  0.445120
# ...          ...       ...       ...       ...       ...       ...       ...
# 599547  0.468571  0.352608  0.472292  0.420896  0.446505  0.463298  0.414223
# 599548  0.468571  0.352608  0.472292  0.420896  0.446505  0.463298  0.414223
# 599549  0.468571  0.352608  0.472292  0.420896  0.446505  0.463298  0.414223
# 599550  0.468571  0.352608  0.472292  0.420896  0.446505  0.463298  0.414223
# 599551  0.468571  0.352608  0.472292  0.420896  0.446505  0.463298  0.414223
#
# [599552 rows x 7 columns]

# %%
table2 = {}
for i in range(7):
    col = str(i)
    N = len(df2[col])
    var2 = []
    for j in range(0, N, 120):
        var2.append(df2[col][j:j + 120].std())
    table2[col] = var2
print(table2)
# Out:
# {'0': [0.0024091772642558158, 0.0015602582026068678, 0.003037803843481139, 0.00228969054245075, 0.0019678026908599325, 0.0024141853323554857, 0.0018658702238690387, 0.0013509913100725574, 0.0030543004918540074, 0.0012553346984812128, 0.0015800222216118234, 0.0016931314516345551, 0.005013176858717151, 0.0030843861237407236, 0.006628078026312528, 0.041487776305110795, 0.007419335802074126, 0.012258020891057405, 0.004052916185339404, 0.00204765390005793, 0.0018848535013644833, 0.003939519792971781, 0.001532967833443006, 0.001572316717254346, 0.0026292747923131357, 0.0028129776829573776, 0.0015715193213792233, 0.004776087345383489, 0.009045607864683761, 0.009782638292669692, 0.004516096442754084, 0.005859650645929727, 0.003504285919811358, 0.0021962437104046505, 0.003563725204694845, 0.0020234475162321007, 0.002625389170765789, 0.0027487642647443735, 0.0016461063761987302, 0.0028426034278939503, 0.0031804383932866618, 0.0042155748569146865, 0.002048498640409459, 0.0037698306675157073, 0.
# ...

# %%
result2 = pd.DataFrame(table2)
result2.to_csv('feature_files/standard_deviation_normalized_merged_autism.csv')
